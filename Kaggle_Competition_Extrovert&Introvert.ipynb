# %% [markdown]
# <a href="https://colab.research.google.com/github/ANUSHREE1403/extrovert-introvert-prediction/blob/main/Kaggle_Competition_Extrovert%26Introvert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import lib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the dataset
train = pd.read_csv('/content/Extrovert-Introvert-train-Data.csv')
test = pd.read_csv('/content/Extrovert-introvert-Test-Data.csv')

# %%
train.head()
# Out:
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
test.head()
# Out:
#       id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0  18524               3.0         No                      7.0            4.0
# 1  18525               NaN        Yes                      0.0            0.0
# 2  18526               3.0         No                      5.0            6.0
# 3  18527               3.0         No                      4.0            4.0
# 4  18528               9.0        Yes                      1.0            2.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency
# 0                        No                  6.0             NaN
# 1                       Yes                  5.0             1.0
# 2                        No                 15.0             9.0
# 3                        No                  5.0             6.0
# 4                       Yes                  1.0             1.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  object
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  object
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6175 entries, 0 to 6174
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         6175 non-null   int64
#  1   Time_spent_Alone           5750 non-null   float64
#  2   Stage_fear                 5577 non-null   object
#  3   Social_event_attendance    5778 non-null   float64
#  4   Going_outside              5709 non-null   float64
#  5   Drained_after_socializing  5743 non-null   object
#  6   Friends_circle_size        5825 non-null   float64
#  7   Post_frequency             5767 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 386.1+ KB

# %%
#shape
print('Shape of training data :',train.shape)
print('Shape of testing data :',test.shape)
# Out:
# Shape of training data : (18524, 9)
# Shape of testing data : (6175, 8)

# %%
#removing duplicates
train.duplicated().sum()
# Out:
# np.int64(0)

# %%
test.duplicated().sum()
# Out:
# np.int64(0)

# %%
#if i have to see row no. which has null values
#masking+isnull
null_train = train.isnull()
train[null_train.any(axis=1)]
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 2          2               6.0        Yes                      1.0
# 4          4               1.0         No                      4.0
# 5          5               2.0         No                      8.0
# 6          6               1.0         No                      8.0
# 8          8               4.0        Yes                      2.0
# ...      ...               ...        ...                      ...
# 18517  18517               3.0         No                      NaN
# 18518  18518               3.0        NaN                      8.0
# 18520  18520               1.0        NaN                      6.0
# 18521  18521               7.0        Yes                      1.0
# 18522  18522               NaN        Yes                      1.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 2                0.0                       NaN                  3.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for x in train.columns:
  if train[x].dtype == 'object':
    train[x].fillna(method='ffill',inplace=True)
    train[x]=le.fit_transform(train[x])
  else:
    train[x].fillna(train[x].mean(),inplace=True)

# %%
for x in test.columns:
  if test[x].dtype == 'object':
    test[x].fillna(method='ffill',inplace=True)
    test[x]=le.fit_transform(test[x])
  else:
    test[x].fillna(test[x].mean(),inplace=True)

# %%
train.shape
# Out:
# (18524, 9)

# %%
train.dropna(how='any')
# Out:
#           id  Time_spent_Alone  Stage_fear  Social_event_attendance  \
# 0          0          0.000000           0                      6.0
# 1          1          1.000000           0                      7.0
# 2          2          6.000000           1                      1.0
# 3          3          3.000000           0                      7.0
# 4          4          1.000000           0                      4.0
# ...      ...               ...         ...                      ...
# 18519  18519          3.000000           0                      7.0
# 18520  18520          1.000000           0                      6.0
# 18521  18521          7.000000           1                      1.0
# 18522  18522          3.137764           1                      1.0
# 18523  18523          1.000000           0                      8.0
#
#        Going_outside  Drained_after_socializing  Friends_circle_size  \
# 0                4.0                          0                 15.0
# ...

# %%
rows_with_multiple_null = train.isnull().sum(axis=1)
rows_with_multiple_null
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 18519    0
# 18520    0
# 18521    0
# 18522    0
# 18523    0
# Length: 18524, dtype: int64

# %%
train[train.isnull().sum(axis=1)>2]
# Out:
# Empty DataFrame
# Columns: [id, Time_spent_Alone, Stage_fear, Social_event_attendance, Going_outside, Drained_after_socializing, Friends_circle_size, Post_frequency, Personality]
# Index: []

# %%
train[train.isnull().sum(axis=1)<=2]
# Out:
#           id  Time_spent_Alone  Stage_fear  Social_event_attendance  \
# 0          0          0.000000           0                      6.0
# 1          1          1.000000           0                      7.0
# 2          2          6.000000           1                      1.0
# 3          3          3.000000           0                      7.0
# 4          4          1.000000           0                      4.0
# ...      ...               ...         ...                      ...
# 18519  18519          3.000000           0                      7.0
# 18520  18520          1.000000           0                      6.0
# 18521  18521          7.000000           1                      1.0
# 18522  18522          3.137764           1                      1.0
# 18523  18523          1.000000           0                      8.0
#
#        Going_outside  Drained_after_socializing  Friends_circle_size  \
# 0                4.0                          0                 15.0
# ...

# %%
train['Stage_fear'].value_counts()
# Out:
# Stage_fear
# 0    14038
# 1     4486
# Name: count, dtype: int64

# %%
train['Stage_fear'].isnull().sum()
# Out:
# np.int64(0)

# %%
train['Stage_fear'].isnull().sum()
# Out:
# np.int64(0)

# %%
train['Drained_after_socializing'].value_counts()
# Out:
# Drained_after_socializing
# 0    14198
# 1     4326
# Name: count, dtype: int64

# %%
train['Drained_after_socializing'].isnull().sum()
# Out:
# np.int64(0)

# %%
for x in train.columns:
  if train[x].dtype == 'object':
    train[x].fillna(method='ffill',inplace=True)
  else:
    train[x].fillna(train[x].mean(),inplace=True)

# %%
for x in test.columns:
  if test[x].dtype == 'object':
    test[x].fillna(method='ffill',inplace=True)
  else:
    test[x].fillna(test[x].mean(),inplace=True)
# Out:
# /tmp/ipython-input-36-1439755800.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[x].fillna(test[x].mean(),inplace=True)
# /tmp/ipython-input-36-1439755800.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
train.isnull().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# dtype: int64

# %%
train.sample()
# Out:
#         id  Time_spent_Alone  Stage_fear  Social_event_attendance  \
# 7055  7055               2.0           0                      4.0
#
#       Going_outside  Drained_after_socializing  Friends_circle_size  \
# 7055            5.0                          0                 11.0
#
#       Post_frequency  Personality
# 7055             3.0            0

# %%
train.columns
# Out:
# Index(['id', 'Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
#        'Going_outside', 'Drained_after_socializing', 'Friends_circle_size',
#        'Post_frequency', 'Personality'],
#       dtype='object')

# %%
x=train.loc[:,['Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
       'Going_outside', 'Drained_after_socializing', 'Friends_circle_size',
       'Post_frequency']]
y=train['Personality']

# %%
x.head()
# Out:
#    Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0               0.0           0                      6.0            4.0
# 1               1.0           0                      7.0            3.0
# 2               6.0           1                      1.0            0.0
# 3               3.0           0                      7.0            3.0
# 4               1.0           0                      4.0            4.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency
# 0                          0                 15.0        5.000000
# 1                          0                 10.0        8.000000
# 2                          0                  3.0        0.000000
# 3                          0                 11.0        5.000000
# 4                          0                 13.0        4.982097

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
LR=LogisticRegression()
DTC=DecisionTreeClassifier()

# %%
LR.fit(x,y)
# Out:
# LogisticRegression()

# %%
DTC.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
print(LR.score(x,y))
print(DTC.score(x,y))
# Out:
# 0.9687432519974087
# 0.9979486072122652

# %%
test.sample()
# Out:
#          id  Time_spent_Alone  Stage_fear  Social_event_attendance  \
# 3064  21588               4.0           0                      6.0
#
#       Going_outside  Drained_after_socializing  Friends_circle_size  \
# 3064            6.0                          0                  7.0
#
#       Post_frequency
# 3064             3.0

# %%
test_x = test.drop('id',axis=1)

# %%
Lr_pred=LR.predict(test_x)
DTC_pred=DTC.predict(test_x)

# %%
print(LR.score(test_x,Lr_pred))
print(DTC.score(test_x,DTC_pred))
# Out:
# 1.0
# 1.0

# %%
train.columns
# Out:
# Index(['id', 'Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
#        'Going_outside', 'Drained_after_socializing', 'Friends_circle_size',
#        'Post_frequency', 'Personality'],
#       dtype='object')

# %%
# create dataframe which has id and pred 'id', 'Personality'
pd.DataFrame({"id":test['id'],"Personality":Lr_pred}).to_csv("submission.csv",index=False)
